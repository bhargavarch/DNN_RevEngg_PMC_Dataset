# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
import plotly.graph_objects as go
import numpy as np
import scipy.signal

window_size = 3
polynomial_order = 2

# %%
df_a = pd.read_csv('data/resnet_list1_data.csv')
df = df_a.loc[78000:88000] 
df.head()

#for column in df:
#    df[column] = scipy.signal.savgol_filter(df[column], window_size, polynomial_order)

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=2100,
    height=550,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=200000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=500000+2*instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=900000+100*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.show()

# %%
#df = df_a.loc[78500:89000] 
#df.to_csv("data/vgg11_list1_data_trimmed.csv", encoding='utf-8', index=False)

# %%
df_b = pd.read_csv('data/vgg16_list1_data.csv')
df = df_b.loc[132000:134500] 
df.head()

#for column in df:
#    df[column] = scipy.signal.savgol_filter(df[column], window_size, polynomial_order)

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=1850,
    height=550,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=1000000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=2000000+2*instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=3000000+100*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.show()

# %%
#df.to_csv("data/mobilenet_list1_data_trimmed.csv", encoding='utf-8', index=False)

# %%
df_c = pd.read_csv('data/alexnet_list1_data.csv')
df = df_c.loc[100000:109500] 
df.head()

#for column in df:
#    df[column] = scipy.signal.savgol_filter(df[column], window_size, polynomial_order)

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=1850,
    height=550,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=200000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=500000+2*instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=900000+100*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.show()

# %%
#df.to_csv("data/resnet_list1_data_trimmed.csv", encoding='utf-8', index=False)

# %%
df = pd.read_csv('data/vgg16_list1_data.csv')
df = df.loc[119000:136000] 
df.to_csv("data/vgg16_unlabeled.csv", encoding='utf-8', index=False)

# %%
df = pd.read_csv('data/vgg16_list1_data.csv')
df = df.loc[119000:136000] 

offset = 0

b1c1_s = 120345
b1c1_f = 121001
b1c2_s = 121156
b1c2_f = 123087
b1mp_s = 123252
b1mp_f = 123353

b2c1_s = 123506
b2c1_f = 123997
b2c2_s = 124293
b2c2_f = 125220
b2mp_s = 125453
b2mp_f = 125494

b3c1_s = 125650
b3c1_f = 126050
b3c2_s = 126288
b3c2_f = 127108
b3c3_s = 127324
b3c3_f = 128145
b3mp_s = 128331
b3mp_f = 128349

b4c1_s = 128507
b4c1_f = 128884
b4c2_s = 129069
b4c2_f = 129833
b4c3_s = 130023
b4c3_f = 130794
b4mp_s = 130963
b4mp_f = 130979

b5c1_s = 131130
b5c1_f = 131331
b5c2_s = 131503
b5c2_f = 131697
b5c3_s = 131868
b5c3_f = 132064
b5mp_s = 132218
b5mp_f = 132230

b6f_s = 132370
b6f_f = 132380

b6de1_s = 132529
b6de1_f = 133971
b6dr1_s = 134124
b6dr1_f = 134132
b6de2_s = 134286
b6de2_f = 134495
b6dr2_s = 134647
b6dr2_f = 134654
b6de3_s = 134796
b6de3_f = 134808


df['label'] = 0
df.loc[offset+b1c1_s:offset+b1c1_f, 'label'] = 6
df.loc[offset+b1c2_s:offset+b1c2_f, 'label'] = 6
df.loc[offset+b1mp_s:offset+b1mp_f, 'label'] = 9

df.loc[offset+b2c1_s:offset+b2c1_f, 'label'] = 6
df.loc[offset+b2c2_s:offset+b2c2_f, 'label'] = 6
df.loc[offset+b2mp_s:offset+b2mp_f, 'label'] = 9

df.loc[offset+b3c1_s:offset+b3c1_f, 'label'] = 6
df.loc[offset+b3c2_s:offset+b3c2_f, 'label'] = 6
df.loc[offset+b3c3_s:offset+b3c3_f, 'label'] = 6
df.loc[offset+b3mp_s:offset+b3mp_f, 'label'] = 9

df.loc[offset+b4c1_s:offset+b4c1_f, 'label'] = 6
df.loc[offset+b4c2_s:offset+b4c2_f, 'label'] = 6
df.loc[offset+b4c3_s:offset+b4c3_f, 'label'] = 6
df.loc[offset+b4mp_s:offset+b4mp_f, 'label'] = 9

df.loc[offset+b5c1_s:offset+b5c1_f, 'label'] = 6
df.loc[offset+b5c2_s:offset+b5c2_f, 'label'] = 6
df.loc[offset+b5c3_s:offset+b5c3_f, 'label'] = 6
df.loc[offset+b5mp_s:offset+b5mp_f, 'label'] = 9

df.loc[offset+b6f_s:offset+b6f_f, 'label'] = 4

df.loc[offset+b6de1_s:offset+b6de1_f, 'label'] = 5
df.loc[offset+b6dr1_s:offset+b6dr1_f, 'label'] = 7
df.loc[offset+b6de2_s:offset+b6de2_f, 'label'] = 5
df.loc[offset+b6dr2_s:offset+b6dr2_f, 'label'] = 7
df.loc[offset+b6de3_s:offset+b6de3_f, 'label'] = 5

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']
label = df['label']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=2100,
    height=650,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=1000000*label,mode='lines+markers',name='label',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=700000+20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=2000000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=4500000+instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=3500000+50*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))

fig1.show()

# %%
df.to_csv("data/vgg16_labeled.csv", encoding='utf-8', index=False)

# %%
df = pd.read_csv('data/alexnet_list1_data.csv')
df = df.loc[100000:109500]  

offset = 0

b1c1_s = 101229
b1c1_f = 101344
b1bn_s = 101524
b1bn_f = 101567
b1act_s = 101714
b1act_f = 101734
b1mp_s = 101882
b1mp_f = 101897

b2c1_s = 102048
b2c1_f = 102327
b2bn_s = 102484
b2bn_f = 102508
b2act_s = 102649
b2act_f = 102661
b2mp_s = 102802
b2mp_f = 102817

b3c1_s = 102963
b3c1_f = 103062
b3bn1_s = 103210
b3bn1_f = 103226
b3act1_s = 103370
b3act1_f = 103376
b3c2_s = 103529
b3c2_f = 103671
b3bn2_s = 103826
b3bn2_f = 103840
b3act2_s = 103985
b3act2_f = 103991
b3c3_s = 104141
b3c3_f = 104238
b3bn3_s = 104391
b3bn3_f = 104402
b3act3_s = 104549
b3act3_f = 104554
b3mp_s = 104698
b3mp_f = 104705

b4f_s = 104848
b4f_f = 104854
b4de1_s = 105006
b4de1_f = 105970
b4bn1_s = 106122
b4bn1_f = 106139
b4act1_s = 106282
b4act1_f = 106289
b4dr1_s = 106430
b4dr1_f = 106438
b4de2_s = 106589
b4de2_f = 106813
b4bn2_s = 106966
b4bn2_f = 106984
b4act2_s = 107127
b4act2_f = 107134
b4dr2_s = 107276
b4dr2_f = 107283
b4de3_s = 107431
b4de3_f = 107492
b4bn3_s = 107640
b4bn3_f = 107657
b4act3_s = 107798
b4act3_f = 107805
b4dr3_s = 107947
b4dr3_f = 107954
b4de4_s = 108095
b4de4_f = 108105
b4bn4_s = 108247
b4bn4_f = 108264
b4act4_s = 108405
b4act4_f = 108412



df['label'] = 0
df.loc[offset+b1c1_s:offset+b1c1_f, 'label'] = 6
df.loc[offset+b1bn_s:offset+b1bn_f, 'label'] = 2
df.loc[offset+b1act_s:offset+b1act_f, 'label'] = 3
df.loc[offset+b1mp_s:offset+b1mp_f, 'label'] = 9

df.loc[offset+b2c1_s:offset+b2c1_f, 'label'] = 6
df.loc[offset+b2bn_s:offset+b2bn_f, 'label'] = 2
df.loc[offset+b2act_s:offset+b2act_f, 'label'] = 3
df.loc[offset+b2mp_s:offset+b2mp_f, 'label'] = 9

df.loc[offset+b3c1_s:offset+b3c1_f, 'label'] = 6
df.loc[offset+b3bn1_s:offset+b3bn1_f, 'label'] = 2
df.loc[offset+b3act1_s:offset+b3act1_f, 'label'] = 3
df.loc[offset+b3c2_s:offset+b3c2_f, 'label'] = 6
df.loc[offset+b3bn2_s:offset+b3bn2_f, 'label'] = 2
df.loc[offset+b3act2_s:offset+b3act2_f, 'label'] = 3
df.loc[offset+b3c3_s:offset+b3c3_f, 'label'] = 6
df.loc[offset+b3bn3_s:offset+b3bn3_f, 'label'] = 2
df.loc[offset+b3act3_s:offset+b3act3_f, 'label'] = 3
df.loc[offset+b3mp_s:offset+b3mp_f, 'label'] = 9

df.loc[offset+b4f_s:offset+b4f_f, 'label'] = 4
df.loc[offset+b4de1_s:offset+b4de1_f, 'label'] = 5
df.loc[offset+b4bn1_s:offset+b4bn1_f, 'label'] = 2
df.loc[offset+b4act1_s:offset+b4act1_f, 'label'] = 3
df.loc[offset+b4dr1_s:offset+b4dr1_f, 'label'] = 7
df.loc[offset+b4de2_s:offset+b4de2_f, 'label'] = 5
df.loc[offset+b4bn2_s:offset+b4bn2_f, 'label'] = 2
df.loc[offset+b4act2_s:offset+b4act2_f, 'label'] = 3
df.loc[offset+b4dr2_s:offset+b4dr2_f, 'label'] = 7
df.loc[offset+b4de3_s:offset+b4de3_f, 'label'] = 5
df.loc[offset+b4bn3_s:offset+b4bn3_f, 'label'] = 2
df.loc[offset+b4act3_s:offset+b4act3_f, 'label'] = 3
df.loc[offset+b4dr3_s:offset+b4dr3_f, 'label'] = 7
df.loc[offset+b4de4_s:offset+b4de4_f, 'label'] = 5
df.loc[offset+b4bn4_s:offset+b4bn4_f, 'label'] = 2
df.loc[offset+b4act4_s:offset+b4act4_f, 'label'] = 3

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']
label = df['label']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=1700,
    height=450,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=1000000*label,mode='lines+markers',name='label',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=700000+20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=2000000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=4500000+instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=3500000+50*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))

fig1.show()

# %%
df.to_csv("data/alexnet_labeled.csv", encoding='utf-8', index=False)

# %%
df = pd.read_csv('data/resnet_list1_data.csv')
df = df.loc[78000:88000]  

offset = 0

b1c_s = 78679
b1c_f = 78743
b1mp_s = 78892
b1mp_f = 78933

b2c_s = 79082
b2c_f = 79162
b2bn_s = 79307
b2bn_f = 79323
b2act_s = 79473
b2act_f =  79483

b3c_s = 79629
b3c_f = 79706
b3bn_s = 79855
b3bn_f = 79873
b3act_s = 80016
b3act_f = 80026

b4c_s = 80176
b4c_f = 80250
b4bn_s = 80397
b4bn_f = 80417
b4act_s = 80559
b4act_f = 80570

b5c_s = 80719
b5c_f = 80791
b5bn_s = 80937
b5bn_f = 80957
b5act_s = 81101
b5act_f = 81112

b6c_s = 81259
b6c_f = 81292
b6bn_s = 81436
b6bn_f = 81453
b6act_s = 81595
b6act_f = 81604

b7c_s = 81740
b7c_f = 81763
b7bn_s = 81907
b7bn_f = 81924
b7act_s = 82062
b7act_f = 82073

b8c_s = 82211
b8c_f = 82232
b8bn_s = 82377
b8bn_f = 82394
b8act_s = 82533
b8act_f = 82543

b9c_s = 82682
b9c_f = 82709
b9bn_s = 82848
b9bn_f = 82865
b9act_s = 83004
b9act_f = 83012

b10c_s = 83152
b10c_f = 83172
b10bn_s = 83314
b10bn_f = 83328
b10act_s = 83469
b10act_f = 83477

b11c_s = 83618
b11c_f = 83640
b11bn_s = 83779
b11bn_f = 83794
b11act_s = 83933
b11act_f = 83943

b12c_s = 84082
b12c_f = 84104
b12bn_s = 84245
b12bn_f = 84260
b12act_s = 84401
b12act_f = 84409

b13c_s = 84550
b13c_f = 84570
b13bn_s = 84712
b13bn_f = 84726
b13act_s = 84867
b13act_f = 84875

b14c_s = 85012
b14c_f = 85040
b14bn_s = 85182
b14bn_f = 85194
b14act_s = 85335
b14act_f = 85342

b15c_s = 85482
b15c_f = 85545
b15bn_s = 85692
b15bn_f = 85702
b15act_s = 85846
b15act_f = 85851

b16c_s = 85994
b16c_f = 86060
b16bn_s = 86203
b16bn_f = 86213
b16act_s = 86357
b16act_f = 86362

b17c_s = 86505
b17c_f = 86570
b17bn_s = 86715
b17bn_f = 86726
b17act_s = 86869
b17act_f = 86874

b18ap_s = 87016
b18ap_f = 87026
b18de_s = 87172
b18de_f = 87186

df['label'] = 0
df.loc[offset+b1c_s:offset+b1c_f, 'label'] = 6
df.loc[offset+b1mp_s:offset+b1mp_f, 'label'] = 9

df.loc[offset+b2c_s:offset+b2c_f, 'label'] = 6
df.loc[offset+b2bn_s:offset+b2bn_f, 'label'] = 2
df.loc[offset+b2act_s:offset+b2act_f, 'label'] = 3

df.loc[offset+b3c_s:offset+b3c_f, 'label'] = 6
df.loc[offset+b3bn_s:offset+b3bn_f, 'label'] = 2
df.loc[offset+b3act_s:offset+b3act_f, 'label'] = 3

df.loc[offset+b4c_s:offset+b4c_f, 'label'] = 6
df.loc[offset+b4bn_s:offset+b4bn_f, 'label'] = 2
df.loc[offset+b4act_s:offset+b4act_f, 'label'] = 3

df.loc[offset+b5c_s:offset+b5c_f, 'label'] = 6
df.loc[offset+b5bn_s:offset+b5bn_f, 'label'] = 2
df.loc[offset+b5act_s:offset+b5act_f, 'label'] = 3

df.loc[offset+b6c_s:offset+b6c_f, 'label'] = 6
df.loc[offset+b6bn_s:offset+b6bn_f, 'label'] = 2
df.loc[offset+b6act_s:offset+b6act_f, 'label'] = 3

df.loc[offset+b7c_s:offset+b7c_f, 'label'] = 6
df.loc[offset+b7bn_s:offset+b7bn_f, 'label'] = 2
df.loc[offset+b7act_s:offset+b7act_f, 'label'] = 3

df.loc[offset+b8c_s:offset+b8c_f, 'label'] = 6
df.loc[offset+b8bn_s:offset+b8bn_f, 'label'] = 2
df.loc[offset+b8act_s:offset+b8act_f, 'label'] = 3

df.loc[offset+b9c_s:offset+b9c_f, 'label'] = 6
df.loc[offset+b9bn_s:offset+b9bn_f, 'label'] = 2
df.loc[offset+b9act_s:offset+b9act_f, 'label'] = 3

df.loc[offset+b10c_s:offset+b10c_f, 'label'] = 6
df.loc[offset+b10bn_s:offset+b10bn_f, 'label'] = 2
df.loc[offset+b10act_s:offset+b10act_f, 'label'] = 3

df.loc[offset+b11c_s:offset+b11c_f, 'label'] = 6
df.loc[offset+b11bn_s:offset+b11bn_f, 'label'] = 2
df.loc[offset+b11act_s:offset+b11act_f, 'label'] = 3

df.loc[offset+b12c_s:offset+b12c_f, 'label'] = 6
df.loc[offset+b12bn_s:offset+b12bn_f, 'label'] = 2
df.loc[offset+b12act_s:offset+b12act_f, 'label'] = 3

df.loc[offset+b13c_s:offset+b13c_f, 'label'] = 6
df.loc[offset+b13bn_s:offset+b13bn_f, 'label'] = 2
df.loc[offset+b13act_s:offset+b13act_f, 'label'] = 3

df.loc[offset+b14c_s:offset+b14c_f, 'label'] = 6
df.loc[offset+b14bn_s:offset+b14bn_f, 'label'] = 2
df.loc[offset+b14act_s:offset+b14act_f, 'label'] = 3

df.loc[offset+b15c_s:offset+b15c_f, 'label'] = 6
df.loc[offset+b15bn_s:offset+b15bn_f, 'label'] = 2
df.loc[offset+b15act_s:offset+b15act_f, 'label'] = 3

df.loc[offset+b16c_s:offset+b16c_f, 'label'] = 6
df.loc[offset+b16bn_s:offset+b16bn_f, 'label'] = 2
df.loc[offset+b16act_s:offset+b16act_f, 'label'] = 3

df.loc[offset+b17c_s:offset+b17c_f, 'label'] = 6
df.loc[offset+b17bn_s:offset+b17bn_f, 'label'] = 2
df.loc[offset+b17act_s:offset+b17act_f, 'label'] = 3

df.loc[offset+b18ap_s:offset+b18ap_f, 'label'] = 8
df.loc[offset+b18de_s:offset+b18de_f, 'label'] = 5

axis_x = df.index.tolist()
branches = df['branches']
cache_misses = df['cache_misses']
instructions = df['instructions']
cache_references = df['cache_references']
label = df['label']

fig1 = go.Figure()

fig1.update_layout(
    autosize=False,
    width=1700,
    height=450,
    margin=go.layout.Margin(
        l=10,
        r=10,
        b=10,
        t=10,
        pad=2
    ),
    paper_bgcolor="LightSteelBlue",
)

fig1.add_trace(go.Scatter(x=axis_x, y=1000000*label,mode='lines+markers',name='label',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=700000+20*branches,mode='lines+markers',name='branches',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=2000000+50*cache_misses,mode='lines+markers',name='cache_misses',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=4500000+instructions,mode='lines+markers',name='instructions',line=dict(width=1,shape='spline'),marker=dict(size=2)))
fig1.add_trace(go.Scatter(x=axis_x, y=3500000+50*cache_references,mode='lines+markers',name='cache_references',line=dict(width=1,shape='spline'),marker=dict(size=2)))

fig1.show()

# %%
df.to_csv("data/resnet_labeled.csv", encoding='utf-8', index=False)
